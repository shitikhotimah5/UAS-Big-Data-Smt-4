# %%
pwd
# Out:
# 'C:\\Users\\ADMIN\\Documents\\ANACONDA\\Pa Humam\\UAS\\ok'

# %%
import pandas as pd

# %%
pd.read_csv('Credit_Card_Applications.csv')
# Out:
#      CustomerID  A1     A2      A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 0      15776156   1  22.08  11.460   2   4   4  1.585   0   0    0    1    2
# 1      15739548   0  22.67   7.000   2   8   4  0.165   0   0    0    0    2
# 2      15662854   0  29.58   1.750   1   4   4  1.250   0   0    0    1    2
# 3      15687688   0  21.67  11.500   1   5   3  0.000   1   1   11    1    2
# 4      15715750   1  20.17   8.170   2   6   4  1.960   1   1   14    0    2
# ..          ...  ..    ...     ...  ..  ..  ..    ...  ..  ..  ...  ...  ...
# 685    15808223   1  31.57  10.500   2  14   4  6.500   1   0    0    0    2
# 686    15769980   1  20.67   0.415   2   8   4  0.125   0   0    0    0    2
# 687    15675450   0  18.83   9.540   2   6   4  0.085   1   0    0    0    2
# 688    15776494   0  27.42  14.500   2  14   8  3.085   1   1    1    0    2
# 689    15592412   1  41.00   0.040   2  10   4  0.040   0   1    1    0    1
#
#      A13   A14  Class
# ...

# %%
dataku = pd.read_csv('Credit_Card_Applications.csv')

# %%
dataku
# Out:
#      CustomerID  A1     A2      A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 0      15776156   1  22.08  11.460   2   4   4  1.585   0   0    0    1    2
# 1      15739548   0  22.67   7.000   2   8   4  0.165   0   0    0    0    2
# 2      15662854   0  29.58   1.750   1   4   4  1.250   0   0    0    1    2
# 3      15687688   0  21.67  11.500   1   5   3  0.000   1   1   11    1    2
# 4      15715750   1  20.17   8.170   2   6   4  1.960   1   1   14    0    2
# ..          ...  ..    ...     ...  ..  ..  ..    ...  ..  ..  ...  ...  ...
# 685    15808223   1  31.57  10.500   2  14   4  6.500   1   0    0    0    2
# 686    15769980   1  20.67   0.415   2   8   4  0.125   0   0    0    0    2
# 687    15675450   0  18.83   9.540   2   6   4  0.085   1   0    0    0    2
# 688    15776494   0  27.42  14.500   2  14   8  3.085   1   1    1    0    2
# 689    15592412   1  41.00   0.040   2  10   4  0.040   0   1    1    0    1
#
#      A13   A14  Class
# ...

# %%
dataku.head()
# Out:
#    CustomerID  A1     A2     A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 0    15776156   1  22.08  11.46   2   4   4  1.585   0   0    0    1    2
# 1    15739548   0  22.67   7.00   2   8   4  0.165   0   0    0    0    2
# 2    15662854   0  29.58   1.75   1   4   4  1.250   0   0    0    1    2
# 3    15687688   0  21.67  11.50   1   5   3  0.000   1   1   11    1    2
# 4    15715750   1  20.17   8.17   2   6   4  1.960   1   1   14    0    2
#
#    A13   A14  Class
# 0  100  1213      0
# 1  160     1      0
# 2  280     1      0
# 3    0     1      1
# 4   60   159      1

# %%
dataku.tail()
# Out:
#      CustomerID  A1     A2      A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 685    15808223   1  31.57  10.500   2  14   4  6.500   1   0    0    0    2
# 686    15769980   1  20.67   0.415   2   8   4  0.125   0   0    0    0    2
# 687    15675450   0  18.83   9.540   2   6   4  0.085   1   0    0    0    2
# 688    15776494   0  27.42  14.500   2  14   8  3.085   1   1    1    0    2
# 689    15592412   1  41.00   0.040   2  10   4  0.040   0   1    1    0    1
#
#      A13  A14  Class
# 685    0    1      1
# 686    0   45      0
# 687  100    1      1
# 688  120   12      1
# 689  560    1      1

# %%
dataku.to_excel('Credit_Card_Applications.xlsx', index=False, sheet_name='uas')

# %%
pd.read_excel('Credit_Card_Applications.xlsx')
# Out:
#      CustomerID  A1     A2      A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 0      15776156   1  22.08  11.460   2   4   4  1.585   0   0    0    1    2
# 1      15739548   0  22.67   7.000   2   8   4  0.165   0   0    0    0    2
# 2      15662854   0  29.58   1.750   1   4   4  1.250   0   0    0    1    2
# 3      15687688   0  21.67  11.500   1   5   3  0.000   1   1   11    1    2
# 4      15715750   1  20.17   8.170   2   6   4  1.960   1   1   14    0    2
# ..          ...  ..    ...     ...  ..  ..  ..    ...  ..  ..  ...  ...  ...
# 685    15808223   1  31.57  10.500   2  14   4  6.500   1   0    0    0    2
# 686    15769980   1  20.67   0.415   2   8   4  0.125   0   0    0    0    2
# 687    15675450   0  18.83   9.540   2   6   4  0.085   1   0    0    0    2
# 688    15776494   0  27.42  14.500   2  14   8  3.085   1   1    1    0    2
# 689    15592412   1  41.00   0.040   2  10   4  0.040   0   1    1    0    1
#
#      A13   A14  Class
# ...

# %%
from sqlalchemy import create_engine

# %%
mesin = create_engine ('sqlite:///:memory:')

# %%
dataku.to_sql('data', con=mesin)

# %%
pd.read_sql('data', con=mesin)
# Out:
#      index  CustomerID  A1     A2      A3  A4  A5  A6     A7  A8  A9  A10  \
# 0        0    15776156   1  22.08  11.460   2   4   4  1.585   0   0    0
# 1        1    15739548   0  22.67   7.000   2   8   4  0.165   0   0    0
# 2        2    15662854   0  29.58   1.750   1   4   4  1.250   0   0    0
# 3        3    15687688   0  21.67  11.500   1   5   3  0.000   1   1   11
# 4        4    15715750   1  20.17   8.170   2   6   4  1.960   1   1   14
# ..     ...         ...  ..    ...     ...  ..  ..  ..    ...  ..  ..  ...
# 685    685    15808223   1  31.57  10.500   2  14   4  6.500   1   0    0
# 686    686    15769980   1  20.67   0.415   2   8   4  0.125   0   0    0
# 687    687    15675450   0  18.83   9.540   2   6   4  0.085   1   0    0
# 688    688    15776494   0  27.42  14.500   2  14   8  3.085   1   1    1
# 689    689    15592412   1  41.00   0.040   2  10   4  0.040   0   1    1
#
#      A11  A12  A13   A14  Class
# 0      1    2  100  1213      0
# ...

# %%
import pandas as pd

# %%
dataku = pd.read_csv('Credit_Card_Applications.csv')

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
pd.options.display.min_rows
# Out:
# 10

# %%
pd.options.display.max_rows = 691

# %%
pd.options.display.min_rows = 691

# %%
pd.options.display.max_rows
# Out:
# 691

# %%
dataku
# Out:
#      CustomerID  A1     A2      A3  A4  A5  A6      A7  A8  A9  A10  A11  A12  \
# 0      15776156   1  22.08  11.460   2   4   4   1.585   0   0    0    1    2
# 1      15739548   0  22.67   7.000   2   8   4   0.165   0   0    0    0    2
# 2      15662854   0  29.58   1.750   1   4   4   1.250   0   0    0    1    2
# 3      15687688   0  21.67  11.500   1   5   3   0.000   1   1   11    1    2
# 4      15715750   1  20.17   8.170   2   6   4   1.960   1   1   14    0    2
# 5      15571121   0  15.83   0.585   2   8   8   1.500   1   1    2    0    2
# 6      15726466   1  17.42   6.500   2   3   4   0.125   0   0    0    0    2
# 7      15660390   0  58.67   4.460   2  11   8   3.040   1   1    6    0    2
# 8      15663942   1  27.83   1.000   1   2   8   3.000   0   0    0    0    2
# 9      15638610   0  55.75   7.080   2   4   8   6.750   1   1    3    1    2
# 10     15644446   1  33.50   1.750   2  14   8   4.500   1   1    4    1    2
# ...

# %%
dataku.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerID  690 non-null    int64
#  1   A1          690 non-null    int64
#  2   A2          690 non-null    float64
#  3   A3          690 non-null    float64
#  4   A4          690 non-null    int64
#  5   A5          690 non-null    int64
#  6   A6          690 non-null    int64
#  7   A7          690 non-null    float64
#  8   A8          690 non-null    int64
#  9   A9          690 non-null    int64
#  10  A10         690 non-null    int64
#  11  A11         690 non-null    int64
#  12  A12         690 non-null    int64
#  13  A13         690 non-null    int64
#  14  A14         690 non-null    int64
#  15  Class       690 non-null    int64
# dtypes: float64(3), int64(13)
# memory usage: 86.4 KB

# %%
dataku.describe()
# Out:
#          CustomerID          A1          A2          A3          A4  \
# count  6.900000e+02  690.000000  690.000000  690.000000  690.000000
# mean   1.569047e+07    0.678261   31.568203    4.758725    1.766667
# std    7.150647e+04    0.467482   11.853273    4.978163    0.430063
# min    1.556571e+07    0.000000   13.750000    0.000000    1.000000
# 25%    1.563169e+07    0.000000   22.670000    1.000000    2.000000
# 50%    1.569016e+07    1.000000   28.625000    2.750000    2.000000
# 75%    1.575190e+07    1.000000   37.707500    7.207500    2.000000
# max    1.581544e+07    1.000000   80.250000   28.000000    3.000000
#
#                A5          A6          A7          A8          A9        A10  \
# count  690.000000  690.000000  690.000000  690.000000  690.000000  690.00000
# mean     7.372464    4.692754    2.223406    0.523188    0.427536    2.40000
# std      3.683265    1.992316    3.346513    0.499824    0.495080    4.86294
# ...

# %%
datahtml = pd.read_html('https://www.kemenkumham.go.id/informasi-publik/laporan-tahunan')

# %%
datahtml
# Out:
# [                  Judul             Penulis        Hit
#  0  Laporan Tahunan 2015  Ditulis oleh Admin  Hit: 3795
#  1  Laporan Tahunan 2016  Ditulis oleh Admin  Hit: 6168
#  2  Laporan Tahunan 2013  Ditulis oleh Admin  Hit: 7936
#  3  Laporan Tahunan 2012  Ditulis oleh Admin  Hit: 6505]

# %%
type(datahtml)
# Out:
# list

# %%
datahtml[0]
# Out:
#                   Judul             Penulis        Hit
# 0  Laporan Tahunan 2015  Ditulis oleh Admin  Hit: 3795
# 1  Laporan Tahunan 2016  Ditulis oleh Admin  Hit: 6168
# 2  Laporan Tahunan 2013  Ditulis oleh Admin  Hit: 7936
# 3  Laporan Tahunan 2012  Ditulis oleh Admin  Hit: 6505

# %%
import pandas as pd 

# The webpage URL whose table we want to extract 
url = "https://www.kemenkumham.go.id/informasi-publik/laporan-tahunan"

# Assign the table data to a Pandas dataframe 
table = pd.read_html(url)[0] 

# Store the dataframe in Excel file 
table.to_excel("datauas.xlsx")
